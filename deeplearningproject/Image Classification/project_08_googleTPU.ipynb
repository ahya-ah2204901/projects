# %%
# tried running it on my own gpu but it was still slow - this just checks your local gpu
# !nvidia-smi
# Out:
# Sun May  4 18:41:25 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.07                 Driver Version: 566.07         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650      WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   40C    P8              5W /   65W |       0MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# imstall these required packagess once
# !pip install -q kaggle
# !pip install -q nltk
# !pip install -q tqdm
# !pip install tensorflow



# Imports
import os
import zipfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# only use when working using gpu of google
import kagglehub
from google.colab import files
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D,  Input, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix


print('imports done!')
# Out:
# imports done!

# %%
# loading the dataset of facial expressions from kaggle !


path = kagglehub.dataset_download("msambare/fer2013")

print("Path to dataset files: ", path)
print("Contents of dataset directory:")
print(os.listdir(path))

# path = r"C:\Users\cai\Documents\6th Semester - Spring 2025\Deep Learning\Project\ferdataset"

# print("Path to dataset files:", path)
# print("Contents of dataset directory:")
# print(os.listdir(path))

# image paths for the dataset
train_dir = os.path.join(path, "train")
val_dir = os.path.join(path, "test")
# Out:
# Path to dataset files:  /kaggle/input/fer2013
# Contents of dataset directory:
# ['test', 'train']

# %%
# since ResNet expects images of size 224x224 RGB we have to resize & normalize!
# do for training and test dataset

# preprocessing data by resizing, normalizing and audmenting the data

image_size = (224, 224)
batch_size = 32

# do data augmentation to the training set for better generalization - this way it wont be dependent on exact inputs
# so we add trasnformations such as rotation, zoom, rescale etc.

train_datagenerator = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# training set
train_generator = train_datagenerator.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    color_mode='rgb',
    class_mode='categorical'
)

# validation set
val_generator = train_datagenerator.flow_from_directory(
    val_dir,
    target_size=image_size,
    batch_size=batch_size,
    color_mode='rgb',
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # **Parameter Training to find the Best Parameters to Train with !**
# DO NOT RUN THIS!!! THIS IS DONEEEEEEE
# Note: This ran for 5hrs

# %% [markdown]
# #** DO NOT RUN THIS!**

# %%
# Grid search values
etas = [1e-5, 1e-4, 1e-3]
epochs_list = [5, 10, 15]

# Best tracking
best_val_acc = 0.0
best_model = None
best_eta = None
best_epochs = None

for eta in etas:
    for n_epochs in epochs_list:

        print(f"Training model with learning rate = {eta}, epochs = {n_epochs}")

        # Build model
        base_res_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
        base_res_model.trainable = False

        x = base_res_model.output
        x = GlobalAveragePooling2D()(x)
        x = Dropout(0.5)(x)
        x = Dense(128, activation='relu')(x)
        x = Dropout(0.3)(x)
        predictions = Dense(train_generator.num_classes, activation='softmax')(x)

        model = Model(inputs=base_res_model.input, outputs=predictions)

        # Compile model
        model.compile(
            optimizer=Adam(learning_rate=eta),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )

        # Train
        early_stop = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True, verbose=0)
        history = model.fit(
            train_generator,
            validation_data=val_generator,
            epochs=n_epochs,
            callbacks=[early_stop],
            verbose=1
        )

        # Check performance
        val_acc = max(history.history['val_accuracy'])
        print(f"Validation Accuracy: {val_acc:.4f}")

        # Save best
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_model = model
            best_eta = eta
            best_epochs = n_epochs
            print("New best model found!")


# make sure to save best model
best_model.save("best_facial_expression_model.keras")
print("\nBest Model Summary:")
print(f"Best Learning Rate: {best_eta}")
print(f"Best Number of Epochs: {best_epochs}")
print(f"Best Validation Accuracy: {best_val_acc:.4f}")
print("Model saved as 'best_facial_expression_model.keras'")

# Download from google colab to my laptop - i do this bcs it doesnt show up sometimes in google collab's temp contents folder
# from google.colab import files
# files.download("best_facial_expression_model.keras")

model.save("best_facial_expression_model.keras")
print("Saved to current directory")
# Out:
# Training model with learning rate = 1e-05, epochs = 5
# Epoch 1/5
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 526s 556ms/step - accuracy: 0.1426 - loss: 2.5028 - val_accuracy: 0.2471 - val_loss: 1.8472
# Epoch 2/5
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 489s 544ms/step - accuracy: 0.1901 - loss: 2.0602 - val_accuracy: 0.2470 - val_loss: 1.8486
# Epoch 3/5
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 491s 547ms/step - accuracy: 0.1964 - loss: 1.9800 - val_accuracy: 0.2473 - val_loss: 1.8381
# Epoch 4/5
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 490s 545ms/step - accuracy: 0.1995 - loss: 1.9402 - val_accuracy: 0.2473 - val_loss: 1.8288
# Epoch 5/5
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 482s 536ms/step - accuracy: 0.1976 - loss: 1.9106 - val_accuracy: 0.2471 - val_loss: 1.8325
# Validation Accuracy: 0.2473
# New best model found!
# Training model with learning rate = 1e-05, epochs = 10
# Epoch 1/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 549s 600ms/step - accuracy: 0.1894 - loss: 2.3924 - val_accuracy: 0.1335 - val_loss: 1.8765
# Epoch 2/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 493s 549ms/step - accuracy: 0.1873 - loss: 2.0951 - val_accuracy: 0.1335 - val_loss: 1.8578
# Epoch 3/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 494s 541ms/step - accuracy: 0.1925 - loss: 1.9930 - val_accuracy: 0.1335 - val_loss: 1.8643
# Epoch 4/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 481s 535ms/step - accuracy: 0.1979 - loss: 1.9489 - val_accuracy: 0.1335 - val_loss: 1.8699
# Validation Accuracy: 0.1335
# Training model with learning rate = 1e-05, epochs = 15
# Epoch 1/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 494s 538ms/step - accuracy: 0.1860 - loss: 2.3652 - val_accuracy: 0.1718 - val_loss: 1.8496
# Epoch 2/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 478s 533ms/step - accuracy: 0.1801 - loss: 2.0899 - val_accuracy: 0.1718 - val_loss: 1.8446
# Epoch 3/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 520s 579ms/step - accuracy: 0.1978 - loss: 1.9855 - val_accuracy: 0.1719 - val_loss: 1.8399
# Epoch 4/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 484s 539ms/step - accuracy: 0.1996 - loss: 1.9477 - val_accuracy: 0.2471 - val_loss: 1.8381
# Epoch 5/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 484s 539ms/step - accuracy: 0.1999 - loss: 1.9194 - val_accuracy: 0.2471 - val_loss: 1.8430
# Epoch 6/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 500s 557ms/step - accuracy: 0.2051 - loss: 1.8964 - val_accuracy: 0.2471 - val_loss: 1.8484
# Validation Accuracy: 0.2471
# Training model with learning rate = 0.0001, epochs = 5
# Epoch 1/5
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 514s 559ms/step - accuracy: 0.1928 - loss: 2.0732 - val_accuracy: 0.1737 - val_loss: 1.8488
# Epoch 2/5
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 487s 542ms/step - accuracy: 0.2183 - loss: 1.8512 - val_accuracy: 0.2471 - val_loss: 1.8376
# Epoch 3/5
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 506s 547ms/step - accuracy: 0.2288 - loss: 1.8363 - val_accuracy: 0.2471 - val_loss: 1.8251
# Epoch 4/5
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 491s 547ms/step - accuracy: 0.2407 - loss: 1.8299 - val_accuracy: 0.2471 - val_loss: 1.8237
# Epoch 5/5
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 494s 551ms/step - accuracy: 0.2436 - loss: 1.8242 - val_accuracy: 0.2471 - val_loss: 1.8232
# Validation Accuracy: 0.2471
# Training model with learning rate = 0.0001, epochs = 10
# Epoch 1/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 559s 609ms/step - accuracy: 0.1788 - loss: 2.1434 - val_accuracy: 0.1718 - val_loss: 1.8312
# Epoch 2/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 498s 554ms/step - accuracy: 0.2191 - loss: 1.8567 - val_accuracy: 0.2471 - val_loss: 1.8227
# Epoch 3/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 490s 545ms/step - accuracy: 0.2356 - loss: 1.8341 - val_accuracy: 0.2471 - val_loss: 1.8233
# Epoch 4/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 505s 549ms/step - accuracy: 0.2445 - loss: 1.8280 - val_accuracy: 0.2471 - val_loss: 1.8177
# Epoch 5/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 479s 534ms/step - accuracy: 0.2454 - loss: 1.8249 - val_accuracy: 0.2471 - val_loss: 1.8156
# Epoch 6/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 484s 539ms/step - accuracy: 0.2505 - loss: 1.8206 - val_accuracy: 0.2471 - val_loss: 1.8129
# Epoch 7/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 510s 547ms/step - accuracy: 0.2503 - loss: 1.8185 - val_accuracy: 0.2473 - val_loss: 1.8103
# Epoch 8/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 474s 528ms/step - accuracy: 0.2525 - loss: 1.8175 - val_accuracy: 0.2471 - val_loss: 1.8089
# Epoch 9/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 480s 534ms/step - accuracy: 0.2520 - loss: 1.8156 - val_accuracy: 0.2471 - val_loss: 1.8081
# Epoch 10/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 479s 533ms/step - accuracy: 0.2478 - loss: 1.8168 - val_accuracy: 0.2474 - val_loss: 1.8078
# Validation Accuracy: 0.2474
# New best model found!
# Training model with learning rate = 0.0001, epochs = 15
# Epoch 1/15
# 857/898 ━━━━━━━━━━━━━━━━━━━━ 17s 424ms/step - accuracy: 0.1858 - loss: 2.0692

# %%
# Grid search values continued
etas = [1e-4, 1e-3]
epochs_list = [5, 10, 15]

# Best tracking
best_val_acc = 0.0
best_model = None
best_eta = None
best_epochs = None

for eta in etas:
    for n_epochs in epochs_list:

        if eta == 1e-4 and (n_epochs == 5 or n_epochs == 10):
          continue

        print(f"Training model with learning rate = {eta}, epochs = {n_epochs}")

        # Build model
        base_res_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
        base_res_model.trainable = False

        x = base_res_model.output
        x = GlobalAveragePooling2D()(x)
        x = Dropout(0.5)(x)
        x = Dense(128, activation='relu')(x)
        x = Dropout(0.3)(x)
        predictions = Dense(train_generator.num_classes, activation='softmax')(x)

        model = Model(inputs=base_res_model.input, outputs=predictions)

        # Compile model
        model.compile(
            optimizer=Adam(learning_rate=eta),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )

        # Train
        early_stop = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True, verbose=0)
        history = model.fit(
            train_generator,
            validation_data=val_generator,
            epochs=n_epochs,
            callbacks=[early_stop],
            verbose=1
        )

        # Check performance
        val_acc = max(history.history['val_accuracy'])
        print(f"Validation Accuracy: {val_acc:.4f}")

        # Save best
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_model = model
            best_eta = eta
            best_epochs = n_epochs
            print("New best model found!")


# make sure to save best model
best_model.save("best_facial_expression_model.keras")
print("\nBest Model Summary:")
print(f"Best Learning Rate: {best_eta}")
print(f"Best Number of Epochs: {best_epochs}")
print(f"Best Validation Accuracy: {best_val_acc:.4f}")
print("Model saved as 'best_facial_expression_model.keras'")

# Download from google colab to my laptop - i do this bcs it doesnt show up sometimes in google collab's temp contents folder
# from google.colab import files
# files.download("best_facial_expression_model.keras")

model.save("best_facial_expression_model.keras")
print("Saved to current directory")
# Out:
# Training model with learning rate = 0.0001, epochs = 15
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 655s 711ms/step - accuracy: 0.1994 - loss: 2.0453 - val_accuracy: 0.1718 - val_loss: 1.8646
# Epoch 2/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 515s 573ms/step - accuracy: 0.2209 - loss: 1.8538 - val_accuracy: 0.2471 - val_loss: 1.8404
# Epoch 3/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 575s 587ms/step - accuracy: 0.2317 - loss: 1.8377 - val_accuracy: 0.2471 - val_loss: 1.8338
# Epoch 4/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 501s 558ms/step - accuracy: 0.2384 - loss: 1.8322 - val_accuracy: 0.2471 - val_loss: 1.8240
# Epoch 5/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 500s 557ms/step - accuracy: 0.2485 - loss: 1.8279 - val_accuracy: 0.2471 - val_loss: 1.8193
# Epoch 6/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 495s 551ms/step - accuracy: 0.2493 - loss: 1.8203 - val_accuracy: 0.2471 - val_loss: 1.8147
# Epoch 7/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 502s 551ms/step - accuracy: 0.2456 - loss: 1.8253 - val_accuracy: 0.2471 - val_loss: 1.8156
# Epoch 8/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 500s 557ms/step - accuracy: 0.2503 - loss: 1.8181 - val_accuracy: 0.2473 - val_loss: 1.8148
# Validation Accuracy: 0.2473
# New best model found!
# Training model with learning rate = 0.001, epochs = 5
# Epoch 1/5
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 518s 564ms/step - accuracy: 0.2277 - loss: 1.8939 - val_accuracy: 0.2471 - val_loss: 1.8144
# Epoch 2/5
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 498s 555ms/step - accuracy: 0.2545 - loss: 1.8108 - val_accuracy: 0.2471 - val_loss: 1.8121
# Epoch 3/5
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 494s 550ms/step - accuracy: 0.2457 - loss: 1.8197 - val_accuracy: 0.2471 - val_loss: 1.8100
# Epoch 4/5
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 507s 557ms/step - accuracy: 0.2536 - loss: 1.8096 - val_accuracy: 0.2471 - val_loss: 1.8054
# Epoch 5/5
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 541s 602ms/step - accuracy: 0.2523 - loss: 1.8126 - val_accuracy: 0.2471 - val_loss: 1.8047
# Validation Accuracy: 0.2471
# Training model with learning rate = 0.001, epochs = 10
# Epoch 1/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 517s 563ms/step - accuracy: 0.2236 - loss: 1.8944 - val_accuracy: 0.2471 - val_loss: 1.8161
# Epoch 2/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 597s 606ms/step - accuracy: 0.2505 - loss: 1.8192 - val_accuracy: 0.2471 - val_loss: 1.8098
# Epoch 3/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 498s 554ms/step - accuracy: 0.2456 - loss: 1.8143 - val_accuracy: 0.2471 - val_loss: 1.8092
# Epoch 4/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 538s 600ms/step - accuracy: 0.2538 - loss: 1.8133 - val_accuracy: 0.2471 - val_loss: 1.8068
# Epoch 5/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 537s 572ms/step - accuracy: 0.2513 - loss: 1.8095 - val_accuracy: 0.2471 - val_loss: 1.8083
# Epoch 6/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 493s 549ms/step - accuracy: 0.2556 - loss: 1.8059 - val_accuracy: 0.2473 - val_loss: 1.8067
# Epoch 7/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 499s 555ms/step - accuracy: 0.2507 - loss: 1.8078 - val_accuracy: 0.2474 - val_loss: 1.8049
# Epoch 8/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 494s 550ms/step - accuracy: 0.2509 - loss: 1.8072 - val_accuracy: 0.2476 - val_loss: 1.8065
# Epoch 9/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 545s 607ms/step - accuracy: 0.2522 - loss: 1.8049 - val_accuracy: 0.2474 - val_loss: 1.8081
# Validation Accuracy: 0.2476
# New best model found!
# Training model with learning rate = 0.001, epochs = 15
# Epoch 1/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 515s 561ms/step - accuracy: 0.2155 - loss: 1.9167 - val_accuracy: 0.2471 - val_loss: 1.8109
# Epoch 2/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 489s 544ms/step - accuracy: 0.2497 - loss: 1.8187 - val_accuracy: 0.2471 - val_loss: 1.8146
# Epoch 3/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 551s 613ms/step - accuracy: 0.2508 - loss: 1.8167 - val_accuracy: 0.2471 - val_loss: 1.8087
# Epoch 4/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 530s 578ms/step - accuracy: 0.2505 - loss: 1.8117 - val_accuracy: 0.2471 - val_loss: 1.8079
# Epoch 5/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 509s 567ms/step - accuracy: 0.2512 - loss: 1.8116 - val_accuracy: 0.2473 - val_loss: 1.8046
# Epoch 6/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 496s 552ms/step - accuracy: 0.2532 - loss: 1.8108 - val_accuracy: 0.2476 - val_loss: 1.8068
# Epoch 7/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 491s 546ms/step - accuracy: 0.2514 - loss: 1.8082 - val_accuracy: 0.2481 - val_loss: 1.8031
# Epoch 8/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 490s 546ms/step - accuracy: 0.2491 - loss: 1.8085 - val_accuracy: 0.2476 - val_loss: 1.8045
# Epoch 9/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 490s 546ms/step - accuracy: 0.2506 - loss: 1.8078 - val_accuracy: 0.2483 - val_loss: 1.8003
# Epoch 10/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 496s 552ms/step - accuracy: 0.2496 - loss: 1.8064 - val_accuracy: 0.2477 - val_loss: 1.8019
# Epoch 11/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 484s 540ms/step - accuracy: 0.2539 - loss: 1.8055 - val_accuracy: 0.2495 - val_loss: 1.8018
# Validation Accuracy: 0.2495
# New best model found!
#
# Best Model Summary:
# Best Learning Rate: 0.001
# Best Number of Epochs: 15
# Best Validation Accuracy: 0.2495
# Model saved as 'best_facial_expression_model.keras'
# Saved to current directory

# %%
from google.colab import files
files.download("best_facial_expression_model.keras")

# %% [markdown]
# Throughout the parameter testing, it can be observed that the validation accuracy would go down after reaching a point which may be Plateauing / its nearing convergence or batches have too much noise.
#
# But! the accuracy was stable-y imporving showing that it didnt plateu completely meaning it will still generalize well. this is where early stopping helped us - it would stop the epoch when there is a drop in accuracy or is barely improving
#
# this shows us that we still need to fine tune it:
# we will try:
#
# *   Fine tune lower levels of the pretrained model - right now were only doing the last layer
# *   We will compare it to another model EfficientNetB0

# %% [markdown]
# # **Plug in the Best Parameters found and Fine Tune the more !**

# %% [markdown]
# were gonna unfreeze some of the deeper layers of this pretrained model using the best params weve taken from the training above

# %%
# ResNet Transfer Layer Model! (starting Transfer Learning)
# we chose this because its already pretrained with imagenet - only planning to train the last layer
# faster and more efficient for our project

# well use Adam Optimizer in ResNet 50

# ------ This code was the very first trial which I based the grid search and fine tuning from --------------

# loading ResNet50 w/o last layer then we freeze!
base_res_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_res_model.trainable = False

# should we do avgpooling or maxpooling???? idk yettt

x = base_res_model.output
x = GlobalAveragePooling2D()(x)
# x = MaxPooling2D(pool_size=(7, 7))(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)

predictions = Dense(train_generator.num_classes, activation='softmax')(x)

# build & save the model !!
model = Model(inputs=base_res_model.input, outputs=predictions)

# Compile it
model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Summary
model.summary()

# %%
# unfreezing and doing further finetuning !

np.random.seed(42)
tf.random.set_seed(42)

# === Phase 1: Build model with frozen base ===
base_res_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_res_model.trainable = False  # freeze all layers

# Add classification head
x = base_res_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
predictions = Dense(train_generator.num_classes, activation='softmax')(x)

# Build the model
model = Model(inputs=base_res_model.input, outputs=predictions)

# Compile with BEST PARAMS found (frozen)
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Phase 1 training
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
print("Phase 1: Training top layers only...")
history_phase1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=15,
    callbacks=[early_stopping],
    verbose=1
)

model.save("phase1_trained_model.keras")
print("Phase 1 model saved!")
files.download("phase1_finetuned_facial_expression_model.keras")
# Out:
# Phase 1: Training top layers only...
# Epoch 1/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 571s 624ms/step - accuracy: 0.2246 - loss: 1.8893 - val_accuracy: 0.2471 - val_loss: 1.8141
# Epoch 2/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 440s 490ms/step - accuracy: 0.2490 - loss: 1.8197 - val_accuracy: 0.2471 - val_loss: 1.8110
# Epoch 3/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 435s 485ms/step - accuracy: 0.2580 - loss: 1.8126 - val_accuracy: 0.2471 - val_loss: 1.8179
# Epoch 4/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 437s 487ms/step - accuracy: 0.2505 - loss: 1.8139 - val_accuracy: 0.2471 - val_loss: 1.8070
# Epoch 5/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 438s 488ms/step - accuracy: 0.2544 - loss: 1.8115 - val_accuracy: 0.2471 - val_loss: 1.8074
# Epoch 6/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 441s 491ms/step - accuracy: 0.2555 - loss: 1.8096 - val_accuracy: 0.2471 - val_loss: 1.8085
# Epoch 7/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 437s 486ms/step - accuracy: 0.2477 - loss: 1.8133 - val_accuracy: 0.2474 - val_loss: 1.8043
# Epoch 8/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 495s 551ms/step - accuracy: 0.2444 - loss: 1.8127 - val_accuracy: 0.2481 - val_loss: 1.8049
# Epoch 9/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 439s 489ms/step - accuracy: 0.2497 - loss: 1.8102 - val_accuracy: 0.2490 - val_loss: 1.8014
# Epoch 10/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 438s 488ms/step - accuracy: 0.2502 - loss: 1.8088 - val_accuracy: 0.2488 - val_loss: 1.8023
# Epoch 11/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 437s 486ms/step - accuracy: 0.2509 - loss: 1.8040 - val_accuracy: 0.2513 - val_loss: 1.7997
# Epoch 12/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 441s 491ms/step - accuracy: 0.2499 - loss: 1.8024 - val_accuracy: 0.2480 - val_loss: 1.8058
# Epoch 13/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 492s 548ms/step - accuracy: 0.2536 - loss: 1.8046 - val_accuracy: 0.2483 - val_loss: 1.8040
# Epoch 14/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 437s 486ms/step - accuracy: 0.2557 - loss: 1.8007 - val_accuracy: 0.2492 - val_loss: 1.7985
# Epoch 15/15
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 438s 488ms/step - accuracy: 0.2524 - loss: 1.8039 - val_accuracy: 0.2477 - val_loss: 1.8036
# Phase 2: Fine-tuning top 30 layers...
# Epoch 1/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.2442 - loss: 1.8224

# %%
from google.colab import files
files.download("best_param_gridsearch_model.keras")

# %%
from tensorflow.keras.models import load_model
base_res_model = load_model("best_param_gridsearch_model.keras")

# %%
# === Phase 2: Fine-tune deeper layers ===
# Unfreeze top 30 layers of ResNet
for layer in base_res_model.layers[-30:]:
    layer.trainable = True

# Re-compile with lower learning rate for fine-tuning
model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Phase 2 training
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
print("Phase 2: Fine-tuning top 30 layers...")
history_phase2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=10,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Phase 2: Fine-tuning top 30 layers...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 605s 661ms/step - accuracy: 0.2462 - loss: 1.8062 - val_accuracy: 0.2478 - val_loss: 1.7994
# Epoch 2/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 477s 532ms/step - accuracy: 0.2486 - loss: 1.8068 - val_accuracy: 0.2484 - val_loss: 1.8002
# Epoch 3/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 519s 578ms/step - accuracy: 0.2548 - loss: 1.8028 - val_accuracy: 0.2485 - val_loss: 1.7997
# Epoch 4/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 469s 522ms/step - accuracy: 0.2478 - loss: 1.8049 - val_accuracy: 0.2494 - val_loss: 1.7996
# Phase 2 model saved!
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-fbc20c8d547c> in <cell line: 0>()
#      23 model.save("phase2_trained_model.keras")
#      24 print("Phase 2 model saved!")
# ---> 25 files.download("phase2_finetuned_facial_expression_model.keras")
#      26
#
# /usr/local/lib/python3.11/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: phase2_finetuned_facial_expression_model.keras

# %%
# Save fine-tuned model
model.save("phase2_trained_model.keras")
print("Phase 2 model saved!")
files.download("phase2_trained_model.keras")
# Out:
# Phase 2 model saved!

# %%
# import tensorflow as tf
# import numpy as np

# Optional: Set seed for reproducibility
# np.random.seed(42)
# tf.random.set_seed(42)

# Load the saved model from Phase 1
# model = load_model("/content/phase1_trained_model.keras")

# %%
# doing early stopping so that it stops training when the valdation loss stops improving
# early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

#train the model
history = model.fit(
   train_generator,
   validation_data=val_generator,
   epochs=10,
   callbacks=[early_stopping]
)

# Save the model to a file
# model.save('facial_exp_resnet50_model.keras')  #Will create a directory that has all the related files and saves everything there

# files.download("facial_exp_resnet50_model.keras")
# saved_model = tf.keras.models.load_model('facial_exp_resnet50_model.keras')
# score = saved_model.evaluate(val_generator)

# print("Testing Loss:", score[0], "Testing Accuracy:", score[1])
# print("Model saved as 'facial_expression_resnet_model'")

# %%
loss, accuracy = model.evaluate(val_generator)
print(f"✅ Test Loss: {loss:.4f}")
print(f"✅ Test Accuracy: {accuracy:.4f}")
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 96s 427ms/step - accuracy: 0.1829 - loss: 1.8199
# ✅ Test Loss: 1.8291
# ✅ Test Accuracy: 0.1797

# %%
# converts softmax probabilities to class labels!
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

model = load_model("/content/best_facial_expression_model.keras")
# Predict probabilities
y_pred_probs = model.predict(val_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

# True labels
y_true = val_generator.classes

# Class labels
class_labels = list(val_generator.class_indices.keys())

# Classification report
print("Classification Report:\n", classification_report(y_true, y_pred, target_names=class_labels))

# %%
# 2. Set your class labels (same order as during training)
class_labels = list(val_generator.class_indices.keys())

# 3. Load and preprocess your image
img_path = "/content/boy.jpg"
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img) / 255.0  # normalize
img_array = np.expand_dims(img_array, axis=0)  # batch shape

# 4. Predict
pred = model.predict(img_array)
pred_class = class_labels[np.argmax(pred)]

print(f"Predicted Expression: {pred_class}")
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ea3bec8b600> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Predicted Expression: happy

# %%
import matplotlib.pyplot as plt

def plot_history(history, title='Model'):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc)+1)

    plt.figure(figsize=(12,5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Train Accuracy')
    plt.plot(epochs, val_acc, 'ro-', label='Val Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Train Loss')
    plt.plot(epochs, val_loss, 'ro-', label='Val Loss')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

#plot_history(history_phase1, title='ResNet50 Phase 1')
#plot_history(history_phase2, title='ResNet50 Phase 2')

# %%
plot_history(history_phase2, title='ResNet50 Phase 2')

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
#confusion matrix for resnet after phase2
# True and predicted labels
y_true = val_generator.classes
y_pred = np.argmax(model.predict(val_generator), axis=1)
class_labels = list(val_generator.class_indices.keys())

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 104s 462ms/step

# %%
from sklearn.metrics import classification_report
#f1 score for resnet after phase2
report = classification_report(y_true, y_pred, target_names=class_labels, output_dict=True)
f1_scores = [report[label]['f1-score'] for label in class_labels]

plt.figure(figsize=(8,4))
plt.bar(class_labels, f1_scores, color='skyblue')
plt.title("Per-Class F1 Score")
plt.ylabel("F1 Score")
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# import matplotlib.pyplot as plt

# # True and predicted labels
# y_true = val_generator.classes
# y_pred = np.argmax(model.predict(val_generator), axis=1)
# class_labels = list(val_generator.class_indices.keys())

# # Confusion matrix
# cm = confusion_matrix(y_true, y_pred)
# disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
# disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)
# plt.title("Confusion Matrix")
# plt.show()

# %%
# from sklearn.metrics import classification_report

# report = classification_report(y_true, y_pred, target_names=class_labels, output_dict=True)
# f1_scores = [report[label]['f1-score'] for label in class_labels]

# plt.figure(figsize=(8, 4))
# plt.bar(class_labels, f1_scores, color='skyblue')
# plt.title("Per-Class F1 Score")
# plt.ylabel("F1 Score")
# plt.xticks(rotation=45)
# plt.show()

# %% [markdown]
# training EffficientNetb0 model to compare accuracy

# %%
# === Import EfficientNetB0 ===
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input as efficient_preprocess
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
# === Use same image generators but with EfficientNet preprocessing ===
train_generator_eff = ImageDataGenerator(
    preprocessing_function=efficient_preprocess,
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
).flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

val_generator_eff = ImageDataGenerator(
    preprocessing_function=efficient_preprocess
).flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# === EfficientNetB0 Base Model ===
base_eff_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_eff_model.trainable = False  # Phase 1: freeze base

# Add classification head
x = base_eff_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.2)(x)
output = Dense(train_generator_eff.num_classes, activation='softmax')(x)

eff_model = Model(inputs=base_eff_model.input, outputs=output)

# Compile for Phase 1
eff_model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# === Phase 1 Training ===
print("Phase 1: Transfer learning with EfficientNetB0...")
history_eff_phase1 = eff_model.fit(
    train_generator_eff,
    validation_data=val_generator_eff,
    epochs=10,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Phase 1: Transfer learning with EfficientNetB0...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 513s 544ms/step - accuracy: 0.2582 - loss: 1.8084 - val_accuracy: 0.3483 - val_loss: 1.6549
# Epoch 2/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 344s 383ms/step - accuracy: 0.3463 - loss: 1.6483 - val_accuracy: 0.3557 - val_loss: 1.6257
# Epoch 3/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 345s 384ms/step - accuracy: 0.3629 - loss: 1.6145 - val_accuracy: 0.3830 - val_loss: 1.5960
# Epoch 4/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 342s 381ms/step - accuracy: 0.3809 - loss: 1.5853 - val_accuracy: 0.3913 - val_loss: 1.5702
# Epoch 5/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 346s 385ms/step - accuracy: 0.3844 - loss: 1.5706 - val_accuracy: 0.3968 - val_loss: 1.5531
# Epoch 6/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 342s 381ms/step - accuracy: 0.3870 - loss: 1.5616 - val_accuracy: 0.4026 - val_loss: 1.5419
# Epoch 7/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 345s 383ms/step - accuracy: 0.3929 - loss: 1.5604 - val_accuracy: 0.4029 - val_loss: 1.5439
# Epoch 8/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 365s 407ms/step - accuracy: 0.3963 - loss: 1.5480 - val_accuracy: 0.4016 - val_loss: 1.5436
# Epoch 9/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 345s 384ms/step - accuracy: 0.4023 - loss: 1.5413 - val_accuracy: 0.3970 - val_loss: 1.5522

# %%
# Save Phase 1 model
eff_model.save("phase1_efficientnet_model.keras")
print("EfficientNetB0 Phase 1 model saved!")
files.download("phase1_efficientnet_model.keras")
# Out:
# EfficientNetB0 Phase 1 model saved!

# %%
plot_history(history_eff_phase1, title='EfficientNetB0 Phase 1')

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
#confusion matrix for efficientnetb0 after phase1
# True and predicted labels
y_true = val_generator_eff.classes
y_pred = np.argmax(eff_model.predict(val_generator_eff), axis=1)
class_labels = list(val_generator_eff.class_indices.keys())

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step

# %% [markdown]
# confusion matrix shows much higher accuracy compared to ResNet model. can see a faint diagonal pattern which shows that the model is getting some accurate results.

# %%
from sklearn.metrics import classification_report
#f1 score for efficientnetb0 after phase1
report = classification_report(y_true, y_pred, target_names=class_labels, output_dict=True)
f1_scores = [report[label]['f1-score'] for label in class_labels]

plt.figure(figsize=(8,4))
plt.bar(class_labels, f1_scores, color='skyblue')
plt.title("Per-Class F1 Score")
plt.ylabel("F1 Score")
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# much more range in class predictions compared to ResNet model.

# %%
# converts softmax probabilities to class labels!
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

model = load_model("/content/phase1_efficientnet_model.keras")
# Predict probabilities
y_pred_probs = model.predict(val_generator_eff)
y_pred = np.argmax(y_pred_probs, axis=1)

# True labels
y_true = val_generator_eff.classes

# Class labels
class_labels = list(val_generator_eff.class_indices.keys())

# Classification report
print("Classification Report:\n", classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 26s 85ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.32      0.19      0.24       958
#      disgust       0.00      0.00      0.00       111
#         fear       0.31      0.09      0.14      1024
#        happy       0.46      0.63      0.53      1774
#      neutral       0.36      0.39      0.37      1233
#          sad       0.32      0.47      0.38      1247
#     surprise       0.61      0.51      0.56       831
#
#     accuracy                           0.40      7178
#    macro avg       0.34      0.33      0.32      7178
# weighted avg       0.39      0.40      0.38      7178
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# 2. Set your class labels (same order as during training)
class_labels = list(val_generator_eff.class_indices.keys())

# 3. Load and preprocess your image
img_path = "/content/man.jpg"
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img) / 255.0  # normalize
img_array = np.expand_dims(img_array, axis=0)  # batch shape

# 4. Predict
pred = model.predict(img_array)
pred_class = class_labels[np.argmax(pred)]

print(f"Predicted Expression: {pred_class}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Predicted Expression: angry

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.optimizers import Adam

# %%
from google.colab import files
files.download("phase1_efficientnet_model.keras")

# %%
from tensorflow.keras.models import load_model

eff_model = load_model("phase1_efficientnet_model.keras")
#load model if not running right after phase1

# %%
# === Phase 2: Fine-tuning ===

# %%
for layer in eff_model.layers[-30:]:
    layer.trainable = True
#use this if using loaded model and not running after phase1

# %%
for layer in base_eff_model.layers[-30:]:
    layer.trainable = True
#use this if running right after phase1

# %%
# === Phase 2: Fine-tuning ===

eff_model.compile(optimizer=Adam(learning_rate=1e-5),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

print("Phase 2: Fine-tuning EfficientNetB0 top 30 layers...")
history_eff_phase2 = eff_model.fit(
    train_generator_eff,
    validation_data=val_generator_eff,
    epochs=10,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Phase 2: Fine-tuning EfficientNetB0 top 30 layers...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 603s 637ms/step - accuracy: 0.3467 - loss: 1.6674 - val_accuracy: 0.3870 - val_loss: 1.6073
# Epoch 2/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 367s 409ms/step - accuracy: 0.3950 - loss: 1.5571 - val_accuracy: 0.4068 - val_loss: 1.5521
# Epoch 3/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 360s 400ms/step - accuracy: 0.4135 - loss: 1.5094 - val_accuracy: 0.4135 - val_loss: 1.5163
# Epoch 4/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 367s 408ms/step - accuracy: 0.4325 - loss: 1.4797 - val_accuracy: 0.4241 - val_loss: 1.4882
# Epoch 5/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 361s 402ms/step - accuracy: 0.4471 - loss: 1.4435 - val_accuracy: 0.4351 - val_loss: 1.4609
# Epoch 6/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 355s 396ms/step - accuracy: 0.4496 - loss: 1.4419 - val_accuracy: 0.4465 - val_loss: 1.4344
# Epoch 7/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 356s 397ms/step - accuracy: 0.4582 - loss: 1.4101 - val_accuracy: 0.4505 - val_loss: 1.4194
# Epoch 8/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 357s 398ms/step - accuracy: 0.4674 - loss: 1.3850 - val_accuracy: 0.4588 - val_loss: 1.3987
# Epoch 9/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 357s 398ms/step - accuracy: 0.4727 - loss: 1.3875 - val_accuracy: 0.4631 - val_loss: 1.3847
# Epoch 10/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 357s 398ms/step - accuracy: 0.4806 - loss: 1.3612 - val_accuracy: 0.4719 - val_loss: 1.3723

# %%
# Save Phase 2 model
eff_model.save("phase2_efficientnet_model.keras")
print("EfficientNetB0 Phase 2 model saved!")
files.download("phase2_efficientnet_model.keras")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9154d51a23f9> in <cell line: 0>()
#       1 # Save Phase 2 model
# ----> 2 eff_model.save("phase2_efficientnet_model.keras")
#       3 print("EfficientNetB0 Phase 2 model saved!")
#       4 files.download("phase2_efficientnet_model.keras")
#
# NameError: name 'eff_model' is not defined

# %%
plot_history(history_eff_phase2, title='EfficientNetB0 Phase 2')

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
#confusion matrix for efficientnetb0 after phase2
# True and predicted labels
y_true = val_generator_eff.classes
y_pred = np.argmax(eff_model.predict(val_generator_eff), axis=1)
class_labels = list(val_generator_eff.class_indices.keys())

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report
#f1 score for efficientnetb0 after phase2
report = classification_report(y_true, y_pred, target_names=class_labels, output_dict=True)
f1_scores = [report[label]['f1-score'] for label in class_labels]

plt.figure(figsize=(8,4))
plt.bar(class_labels, f1_scores, color='skyblue')
plt.title("Per-Class F1 Score")
plt.ylabel("F1 Score")
plt.xticks(rotation=45)
plt.show()

# %%
# converts softmax probabilities to class labels!
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

model = load_model("/content/phase2_efficientnet_model.keras")
# Predict probabilities
y_pred_probs = model.predict(val_generator_eff)
y_pred = np.argmax(y_pred_probs, axis=1)

# True labels
y_true = val_generator_eff.classes

# Class labels
class_labels = list(val_generator_eff.class_indices.keys())

# Classification report
print("Classification Report:\n", classification_report(y_true, y_pred, target_names=class_labels))

# %%
# 2. Set your class labels (same order as during training)
class_labels = list(val_generator_eff.class_indices.keys())

# 3. Load and preprocess your image
img_path = "/content/boy.jpg"
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img) / 255.0  # normalize
img_array = np.expand_dims(img_array, axis=0)  # batch shape

# 4. Predict
pred = model.predict(img_array)
pred_class = class_labels[np.argmax(pred)]

print(f"Predicted Expression: {pred_class}")
